# %%
import pandas as pd
from lib.toml_utils import read_toml

# %%
# get the metrics output
df = read_toml('../cache/judge_predictions_output.toml', "contracts")
df
# Out:
#                                                 code  \
# 0  contract EtherStore {\n    mapping(address => ...
# 1  contract TimeLock {\n    mapping(address => ui...
# 2  contract EtherGame {\n    uint public targetAm...
# 3  contract Vault {\n    uint public count = 123;...
# 4  contract FindThisHash {\n    bytes32 public co...
# 5  // SPDX-License-Identifier: MIT\npragma solidi...
# 6  pragma solidity ^0.8.20;\n\ncontract Target {\...
# 7  contract Wallet {\n    address public owner;\n...
# 8  // file: contracts/UnstoppableVault.sol\n// SP...
#
#                             gpt-3.5-turbo_prediction  \
# 0  1) Reentrancy - The withdraw() function allows...
# 1  1) Reentrancy - The contract is vulnerable to ...
# 2  1) Reentrancy - The claimReward function allow...
# 3  1) Information Leakage - The password variable...
# 4  1) Reentrancy - The contract is vulnerable to ...
# 5  1) Reentrancy - The transfer function uses the...
# 6  1) Reentrancy - The function `protected` in th...
# 7  1) Authorization - The function transfer does ...
# 8  1) Reentrancy - The contract imports "solmate/...
#
#                               gpt-4-turbo_prediction  \
# 0  1) Reentrancy - The withdraw function is vulne...
# 1  1) Reentrancy - The `withdraw` function sends ...
# 2  1) Denial of Service (DoS) - The `deposit` fun...
# 3  1) Authentication - The constructor sets the o...
# 4  1) Reentrancy - The `solve` function sends Eth...
# 5  1) Reentrancy - The `transfer` function sends ...
# 6  1) Re-entrancy Vulnerability - The `protected`...
# 7  1) Authentication through tx.origin - The cont...
# 8  1) Reentrancy - The `flashLoan` function allow...
#
#   gpt-3.5-turbo_false_negatives  \
# 0                            []
# 1                   [arthmetic]
# 2                 [force-ether]
# 3              [secret-storage]
# 4               [front-running]
# 5               [replay-attack]
# 6                            []
# 7                   [tx-origin]
# 8                         [dos]
#
#                        gpt-3.5-turbo_false_positives  \
# 0                                                 []
# 1           [Reentrancy, Integer Overflow/Underflow]
# 2                     [Reentrancy, Integer Overflow]
# 3  [Lack of Access Control, Lack of Input Validat...
# 4  [Reentrancy, Lack of Access Control, Plain Tex...
# 5  [Reentrancy, Lack of Access Control, Front Run...
# 6                                       [Reentrancy]
# 7                                    [Authorization]
# 8  [Reentrancy, Unchecked Return Value, Lack of I...
#
#   gpt-3.5-turbo_true_positives gpt-4-turbo_false_negatives  \
# 0             [reentrancy-eth]                          []
# 1                           []                 [arthmetic]
# 2                           []                          []
# 3        [Information Leakage]            [secret-storage]
# 4                           []             [front-running]
# 5                           []             [replay-attack]
# 6            [zero-size-check]           [zero-size-check]
# 7                           []                          []
# 8                           []                       [dos]
#
#                          gpt-4-turbo_false_positives  \
# 0                           [Missing Access Control]
# 1  [Reentrancy, Denial of Service (DoS), Timestam...
# 2               [Reentrancy, Missing Access Control]
# 3  [Authentication, Integer Overflow/Underflow, G...
# 4  [Reentrancy, Denial of Service (DoS), Gas Limi...
# 5  [Reentrancy, Fixed Array of Owners, Lack of Ev...
# 6  [Re-entrancy Vulnerability, Incorrect Access C...
# 7  [Reentrancy, Missing Input Validation, No With...
# 8  [Reentrancy, Timestamp Dependence, Erroneous L...
#
#                       gpt-4-turbo_true_positives  \
# 0                                   [Reentrancy]
# 1                                             []
# 2                                  [force-ether]
# 3                       [Privacy, Data Exposure]
# 4                                             []
# 5  [Signature Malleability, Hash Collision Risk]
# 6                                             []
# 7                                    [tx-origin]
# 8                                             []
#
#                                               issues
# 0  [{'category': 'reentrancy-eth', 'location': 'E...
# 1  [{'category': 'arthmetic', 'location': 'TimeLo...
# 2  [{'category': 'force-ether', 'location': 'Ethe...
# 3  [{'category': 'secret-storage', 'location': 'V...
# 4  [{'category': 'front-running', 'location': 'Fi...
# 5  [{'category': 'replay-attack', 'location': 'Mu...
# 6  [{'category': 'zero-size-check', 'location': '...
# 7  [{'category': 'tx-origin', 'location': 'Wallet...
# 8  [{'category': 'dos', 'location': 'UnstoppableV...

# %%
# select issues column
if df["issues"] is not None:
    df['issues'] = df["issues"].apply(lambda issues: list(map(lambda i: i['category'], issues)) if issues is not None else None)

df
# Out:
#                                                 code  \
# 0  contract EtherStore {\n    mapping(address => ...
# 1  contract TimeLock {\n    mapping(address => ui...
# 2  contract EtherGame {\n    uint public targetAm...
# 3  contract Vault {\n    uint public count = 123;...
# 4  contract FindThisHash {\n    bytes32 public co...
# 5  // SPDX-License-Identifier: MIT\npragma solidi...
# 6  pragma solidity ^0.8.20;\n\ncontract Target {\...
# 7  contract Wallet {\n    address public owner;\n...
# 8  // file: contracts/UnstoppableVault.sol\n// SP...
#
#                             gpt-3.5-turbo_prediction  \
# 0  1) Reentrancy - The withdraw() function allows...
# 1  1) Reentrancy - The contract is vulnerable to ...
# 2  1) Reentrancy - The claimReward function allow...
# 3  1) Information Leakage - The password variable...
# 4  1) Reentrancy - The contract is vulnerable to ...
# 5  1) Reentrancy - The transfer function uses the...
# 6  1) Reentrancy - The function `protected` in th...
# 7  1) Authorization - The function transfer does ...
# 8  1) Reentrancy - The contract imports "solmate/...
#
#                               gpt-4-turbo_prediction  \
# 0  1) Reentrancy - The withdraw function is vulne...
# 1  1) Reentrancy - The `withdraw` function sends ...
# 2  1) Denial of Service (DoS) - The `deposit` fun...
# 3  1) Authentication - The constructor sets the o...
# 4  1) Reentrancy - The `solve` function sends Eth...
# 5  1) Reentrancy - The `transfer` function sends ...
# 6  1) Re-entrancy Vulnerability - The `protected`...
# 7  1) Authentication through tx.origin - The cont...
# 8  1) Reentrancy - The `flashLoan` function allow...
#
#   gpt-3.5-turbo_false_negatives  \
# 0                            []
# 1                   [arthmetic]
# 2                 [force-ether]
# 3              [secret-storage]
# 4               [front-running]
# 5               [replay-attack]
# 6                            []
# 7                   [tx-origin]
# 8                         [dos]
#
#                        gpt-3.5-turbo_false_positives  \
# 0                                                 []
# 1           [Reentrancy, Integer Overflow/Underflow]
# 2                     [Reentrancy, Integer Overflow]
# 3  [Lack of Access Control, Lack of Input Validat...
# 4  [Reentrancy, Lack of Access Control, Plain Tex...
# 5  [Reentrancy, Lack of Access Control, Front Run...
# 6                                       [Reentrancy]
# 7                                    [Authorization]
# 8  [Reentrancy, Unchecked Return Value, Lack of I...
#
#   gpt-3.5-turbo_true_positives gpt-4-turbo_false_negatives  \
# 0             [reentrancy-eth]                          []
# 1                           []                 [arthmetic]
# 2                           []                          []
# 3        [Information Leakage]            [secret-storage]
# 4                           []             [front-running]
# 5                           []             [replay-attack]
# 6            [zero-size-check]           [zero-size-check]
# 7                           []                          []
# 8                           []                       [dos]
#
#                          gpt-4-turbo_false_positives  \
# 0                           [Missing Access Control]
# 1  [Reentrancy, Denial of Service (DoS), Timestam...
# 2               [Reentrancy, Missing Access Control]
# 3  [Authentication, Integer Overflow/Underflow, G...
# 4  [Reentrancy, Denial of Service (DoS), Gas Limi...
# 5  [Reentrancy, Fixed Array of Owners, Lack of Ev...
# 6  [Re-entrancy Vulnerability, Incorrect Access C...
# 7  [Reentrancy, Missing Input Validation, No With...
# 8  [Reentrancy, Timestamp Dependence, Erroneous L...
#
#                       gpt-4-turbo_true_positives             issues
# 0                                   [Reentrancy]   [reentrancy-eth]
# 1                                             []        [arthmetic]
# 2                                  [force-ether]      [force-ether]
# 3                       [Privacy, Data Exposure]   [secret-storage]
# 4                                             []    [front-running]
# 5  [Signature Malleability, Hash Collision Risk]    [replay-attack]
# 6                                             []  [zero-size-check]
# 7                                    [tx-origin]        [tx-origin]
# 8                                             []              [dos]
