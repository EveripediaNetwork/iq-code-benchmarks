# %%
import pandas as pd
from lib.toml_utils import read_toml

# %%
# get the metrics output
df = read_toml('../cache/calculate_metrics_output.toml', "contracts")
df
# Out:
#                                                 code  \
# 0  contract EtherStore {\n    mapping(address => ...
# 1  pragma solidity ^0.6.0;\ncontract TimeLock {\n...
# 2  contract EtherGame {\n    uint public targetAm...
# 3  contract Vault {\n    uint public count = 123;...
# 4  contract FindThisHash {\n    bytes32 public co...
# 5  // SPDX-License-Identifier: MIT\npragma solidi...
# 6  pragma solidity ^0.8.20;\n\ncontract Target {\...
# 7  contract Wallet {\n    address public owner;\n...
# 8  pragma solidity ^0.8.0;\n\ncontract SecureVaul...
# 9  // A chain-game contract that maintains a 'thr...
#
#                             gpt-3.5-turbo_prediction  \
# 0  1) Medium - Reentrancy Vulnerability [High]\nD...
# 1  1) Medium - Reentrancy Vulnerability [High]\nT...
# 2  1) High - Reentrancy Vulnerability [Critical]\...
# 3  1) Medium - Unprotected Ether Transfer in Cons...
# 4  1) Medium - Lack of input validation [Moderate...
# 5  1) Medium - Lack of Access Control [High]\nThe...
# 6  1) Medium - Lack of Access Control [Low]\nThe ...
# 7  1) Medium - Lack of Access Control [High]\nThe...
# 8  1) Medium - Lack of Access Control in deposit(...
# 9  1) Medium - Privilege Escalation - The wizardA...
#
#                               gpt-4-turbo_prediction  \
# 0  1) High - Reentrancy vulnerability [financial ...
# 1  1) High - Reentrancy vulnerability [Economic/F...
# 2  1) High - Reentrancy Vulnerability [financial ...
# 3  1) High - Unprotected function vulnerability [...
# 4  1) High - Reentrancy vulnerability [financial ...
# 5  1) High - Missing signature verification metho...
# 6  1) High - Phishing with tx.origin\nThe contrac...
# 7  1) High - The use of tx.origin for authenticat...
# 8  1) High - Reentrancy vulnerability in `withdra...
# 9  1) High - Reentrancy vulnerability [Financial ...
#
#                        gpt-3.5-turbo_false_negatives  \
# 0                                                 []
# 1                              [Arithmetic Overflow]
# 2                                [Denial of Service]
# 3                              [Private Information]
# 4                                    [Front Running]
# 5                                 [Signature Replay]
# 6                                                 []
# 7                                                 []
# 8  [Lack of Input Validation, Reentrancy, Uncheck...
# 9                          [Unchecked External Call]
#
#                        gpt-3.5-turbo_false_positives  \
# 0  [Lack of Access Control, Redundant Variable De...
# 1  [Reentrancy Vulnerability, Lack of Access Cont...
# 2  [Reentrancy Vulnerability, Lack of Access Cont...
# 3  [Unprotected Ether Transfer in Constructor, La...
# 4  [Lack of input validation, Reentrancy vulnerab...
# 5  [Lack of Access Control, Lack of Input Validat...
# 6  [Lack of Access Control, External Contract Int...
# 7  [Lack of Access Control, Lack of Input Validat...
# 8             [Lack of Access Control, Optimization]
# 9  [Privilege Escalation, Integer Overflow, Gas E...
#
#   gpt-3.5-turbo_true_positives  \
# 0                 [Reentrancy]
# 1                           []
# 2                           []
# 3                           []
# 4                           []
# 5                           []
# 6    [Reliance on extcodesize]
# 7    [Dependency on tx.origin]
# 8                           []
# 9                           []
#
#                          gpt-4-turbo_false_negatives  \
# 0                                                 []
# 1                              [Arithmetic Overflow]
# 2                                                 []
# 3                              [Private Information]
# 4                                    [Front Running]
# 5                                                 []
# 6                                  [Zero Size Check]
# 7                                                 []
# 8  [Lack of Input Validation, Use of Deprecated S...
# 9                                                 []
#
#                          gpt-4-turbo_false_positives  \
# 0  [Unchecked return value for low-level call, Op...
# 1  [Reentrancy, Denial of Service (DoS) via block...
# 2  [Reentrancy Vulnerability, Unchecked send, Mis...
# 3  [Unprotected function vulnerability, Inefficie...
# 4  [Reentrancy, Unchecked external call, Missing ...
# 5  [Missing signature verification method, Use of...
# 6  [Phishing with tx.origin, Delegatecall to Untr...
# 7  [Reentrancy, Gas optimization and security imp...
# 8  [Reentrancy vulnerability in `withdrawBalance`...
# 9  [Reentrancy vulnerability, Denial of Service b...
#
#                           gpt-4-turbo_true_positives  gpt-3.5-turbo_recall  \
# 0                                       [Reentrancy]                   1.0
# 1                                                 []                   0.0
# 2                                [Denial of Service]                   0.0
# 3    [Hardcoded sensitive information vulnerability]                   0.0
# 4                                                 []                   0.0
# 5                                 [Signature Replay]                   0.0
# 6                                                 []                   1.0
# 7                                 [Use of tx.origin]                   1.0
# 8  [Reentrancy, Unchecked External Call, Insecure...                   0.0
# 9                [Unchecked return value for send()]                   0.0
#
#    gpt-3.5-turbo_precision  gpt-3.5-turbo_f1_score  gpt-3.5-turbo_accuracy  \
# 0                     0.25                     0.4                    0.25
# 1                     0.00                     0.0                    0.00
# 2                     0.00                     0.0                    0.00
# 3                     0.00                     0.0                    0.00
# 4                     0.00                     0.0                    0.00
# 5                     0.00                     0.0                    0.00
# 6                     0.25                     0.4                    0.25
# 7                     0.25                     0.4                    0.25
# 8                     0.00                     0.0                    0.00
# 9                     0.00                     0.0                    0.00
#
#    gpt-4-turbo_recall  gpt-4-turbo_precision  gpt-4-turbo_f1_score  \
# 0            1.000000               0.333333              0.500000
# 1            0.000000               0.000000              0.000000
# 2            1.000000               0.250000              0.400000
# 3            0.500000               0.125000              0.200000
# 4            0.000000               0.000000              0.000000
# 5            1.000000               0.100000              0.181818
# 6            0.000000               0.000000              0.000000
# 7            1.000000               0.333333              0.500000
# 8            0.333333               0.375000              0.352941
# 9            1.000000               0.125000              0.222222
#
#    gpt-4-turbo_accuracy                                             issues
# 0              0.333333  [{'category': 'Reentrancy', 'location': 'Ether...
# 1              0.000000  [{'category': 'Arithmetic Overflow', 'location...
# 2              0.250000  [{'category': 'Denial of Service', 'location':...
# 3              0.111111  [{'category': 'Private Information', 'location...
# 4              0.000000  [{'category': 'Front Running', 'location': 'Fi...
# 5              0.100000  [{'category': 'Signature Replay', 'location': ...
# 6              0.000000  [{'category': 'Zero Size Check', 'location': '...
# 7              0.333333  [{'category': 'Use of tx.origin', 'location': ...
# 8              0.214286  [{'category': 'Lack of Input Validation', 'loc...
# 9              0.125000  [{'category': 'Unchecked External Call', 'loca...

# %%
# select issues column
if df["issues"] is not None:
    df['issues'] = df["issues"].apply(lambda issues: list(map(lambda i: i['category'], issues)) if issues is not None else None)

df
# Out:
#                                                 code  \
# 0  contract EtherStore {\n    mapping(address => ...
# 1  pragma solidity ^0.6.0;\ncontract TimeLock {\n...
# 2  contract EtherGame {\n    uint public targetAm...
# 3  contract Vault {\n    uint public count = 123;...
# 4  contract FindThisHash {\n    bytes32 public co...
# 5  // SPDX-License-Identifier: MIT\npragma solidi...
# 6  pragma solidity ^0.8.20;\n\ncontract Target {\...
# 7  contract Wallet {\n    address public owner;\n...
# 8  pragma solidity ^0.8.0;\n\ncontract SecureVaul...
# 9  // A chain-game contract that maintains a 'thr...
#
#                             gpt-3.5-turbo_prediction  \
# 0  1) Medium - Reentrancy Vulnerability [High]\nD...
# 1  1) Medium - Reentrancy Vulnerability [High]\nT...
# 2  1) High - Reentrancy Vulnerability [Critical]\...
# 3  1) Medium - Unprotected Ether Transfer in Cons...
# 4  1) Medium - Lack of input validation [Moderate...
# 5  1) Medium - Lack of Access Control [High]\nThe...
# 6  1) Medium - Lack of Access Control [Low]\nThe ...
# 7  1) Medium - Lack of Access Control [High]\nThe...
# 8  1) Medium - Lack of Access Control in deposit(...
# 9  1) Medium - Privilege Escalation - The wizardA...
#
#                               gpt-4-turbo_prediction  \
# 0  1) High - Reentrancy vulnerability [financial ...
# 1  1) High - Reentrancy vulnerability [Economic/F...
# 2  1) High - Reentrancy Vulnerability [financial ...
# 3  1) High - Unprotected function vulnerability [...
# 4  1) High - Reentrancy vulnerability [financial ...
# 5  1) High - Missing signature verification metho...
# 6  1) High - Phishing with tx.origin\nThe contrac...
# 7  1) High - The use of tx.origin for authenticat...
# 8  1) High - Reentrancy vulnerability in `withdra...
# 9  1) High - Reentrancy vulnerability [Financial ...
#
#                        gpt-3.5-turbo_false_negatives  \
# 0                                                 []
# 1                              [Arithmetic Overflow]
# 2                                [Denial of Service]
# 3                              [Private Information]
# 4                                    [Front Running]
# 5                                 [Signature Replay]
# 6                                                 []
# 7                                                 []
# 8  [Lack of Input Validation, Reentrancy, Uncheck...
# 9                          [Unchecked External Call]
#
#                        gpt-3.5-turbo_false_positives  \
# 0  [Lack of Access Control, Redundant Variable De...
# 1  [Reentrancy Vulnerability, Lack of Access Cont...
# 2  [Reentrancy Vulnerability, Lack of Access Cont...
# 3  [Unprotected Ether Transfer in Constructor, La...
# 4  [Lack of input validation, Reentrancy vulnerab...
# 5  [Lack of Access Control, Lack of Input Validat...
# 6  [Lack of Access Control, External Contract Int...
# 7  [Lack of Access Control, Lack of Input Validat...
# 8             [Lack of Access Control, Optimization]
# 9  [Privilege Escalation, Integer Overflow, Gas E...
#
#   gpt-3.5-turbo_true_positives  \
# 0                 [Reentrancy]
# 1                           []
# 2                           []
# 3                           []
# 4                           []
# 5                           []
# 6    [Reliance on extcodesize]
# 7    [Dependency on tx.origin]
# 8                           []
# 9                           []
#
#                          gpt-4-turbo_false_negatives  \
# 0                                                 []
# 1                              [Arithmetic Overflow]
# 2                                                 []
# 3                              [Private Information]
# 4                                    [Front Running]
# 5                                                 []
# 6                                  [Zero Size Check]
# 7                                                 []
# 8  [Lack of Input Validation, Use of Deprecated S...
# 9                                                 []
#
#                          gpt-4-turbo_false_positives  \
# 0  [Unchecked return value for low-level call, Op...
# 1  [Reentrancy, Denial of Service (DoS) via block...
# 2  [Reentrancy Vulnerability, Unchecked send, Mis...
# 3  [Unprotected function vulnerability, Inefficie...
# 4  [Reentrancy, Unchecked external call, Missing ...
# 5  [Missing signature verification method, Use of...
# 6  [Phishing with tx.origin, Delegatecall to Untr...
# 7  [Reentrancy, Gas optimization and security imp...
# 8  [Reentrancy vulnerability in `withdrawBalance`...
# 9  [Reentrancy vulnerability, Denial of Service b...
#
#                           gpt-4-turbo_true_positives  gpt-3.5-turbo_recall  \
# 0                                       [Reentrancy]                   1.0
# 1                                                 []                   0.0
# 2                                [Denial of Service]                   0.0
# 3    [Hardcoded sensitive information vulnerability]                   0.0
# 4                                                 []                   0.0
# 5                                 [Signature Replay]                   0.0
# 6                                                 []                   1.0
# 7                                 [Use of tx.origin]                   1.0
# 8  [Reentrancy, Unchecked External Call, Insecure...                   0.0
# 9                [Unchecked return value for send()]                   0.0
#
#    gpt-3.5-turbo_precision  gpt-3.5-turbo_f1_score  gpt-3.5-turbo_accuracy  \
# 0                     0.25                     0.4                    0.25
# 1                     0.00                     0.0                    0.00
# 2                     0.00                     0.0                    0.00
# 3                     0.00                     0.0                    0.00
# 4                     0.00                     0.0                    0.00
# 5                     0.00                     0.0                    0.00
# 6                     0.25                     0.4                    0.25
# 7                     0.25                     0.4                    0.25
# 8                     0.00                     0.0                    0.00
# 9                     0.00                     0.0                    0.00
#
#    gpt-4-turbo_recall  gpt-4-turbo_precision  gpt-4-turbo_f1_score  \
# 0            1.000000               0.333333              0.500000
# 1            0.000000               0.000000              0.000000
# 2            1.000000               0.250000              0.400000
# 3            0.500000               0.125000              0.200000
# 4            0.000000               0.000000              0.000000
# 5            1.000000               0.100000              0.181818
# 6            0.000000               0.000000              0.000000
# 7            1.000000               0.333333              0.500000
# 8            0.333333               0.375000              0.352941
# 9            1.000000               0.125000              0.222222
#
#    gpt-4-turbo_accuracy                                             issues
# 0              0.333333                                       [Reentrancy]
# 1              0.000000                              [Arithmetic Overflow]
# 2              0.250000                                [Denial of Service]
# 3              0.111111                              [Private Information]
# 4              0.000000                                    [Front Running]
# 5              0.100000                                 [Signature Replay]
# 6              0.000000                                  [Zero Size Check]
# 7              0.333333                                 [Use of tx.origin]
# 8              0.214286  [Lack of Input Validation, Reentrancy, Uncheck...
# 9              0.125000                          [Unchecked External Call]

# %%
# Get keys that have x in its name
def get_keys(df, x):
    return list(filter(lambda key: x in key, df.columns))

# %%
recall_keys = get_keys(df, 'recall')
positive_keys = get_keys(df, 'positive')
negative_keys = get_keys(df, 'negative')


# filter the dataframe to only have the recall and prediction columns 
# and sort by recall and only select all recall columns < 0.5
df[recall_keys + positive_keys + negative_keys + ['issues']].where(df[recall_keys].max(axis=1) < 0.5)
# Out:
#    gpt-3.5-turbo_recall  gpt-4-turbo_recall  \
# 0                   NaN                 NaN
# 1                   0.0            0.000000
# 2                   NaN                 NaN
# 3                   NaN                 NaN
# 4                   0.0            0.000000
# 5                   NaN                 NaN
# 6                   NaN                 NaN
# 7                   NaN                 NaN
# 8                   0.0            0.333333
# 9                   NaN                 NaN
#
#                        gpt-3.5-turbo_false_positives  \
# 0                                                NaN
# 1  [Reentrancy Vulnerability, Lack of Access Cont...
# 2                                                NaN
# 3                                                NaN
# 4  [Lack of input validation, Reentrancy vulnerab...
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8             [Lack of Access Control, Optimization]
# 9                                                NaN
#
#   gpt-3.5-turbo_true_positives  \
# 0                          NaN
# 1                           []
# 2                          NaN
# 3                          NaN
# 4                           []
# 5                          NaN
# 6                          NaN
# 7                          NaN
# 8                           []
# 9                          NaN
#
#                          gpt-4-turbo_false_positives  \
# 0                                                NaN
# 1  [Reentrancy, Denial of Service (DoS) via block...
# 2                                                NaN
# 3                                                NaN
# 4  [Reentrancy, Unchecked external call, Missing ...
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8  [Reentrancy vulnerability in `withdrawBalance`...
# 9                                                NaN
#
#                           gpt-4-turbo_true_positives  \
# 0                                                NaN
# 1                                                 []
# 2                                                NaN
# 3                                                NaN
# 4                                                 []
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8  [Reentrancy, Unchecked External Call, Insecure...
# 9                                                NaN
#
#                        gpt-3.5-turbo_false_negatives  \
# 0                                                NaN
# 1                              [Arithmetic Overflow]
# 2                                                NaN
# 3                                                NaN
# 4                                    [Front Running]
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8  [Lack of Input Validation, Reentrancy, Uncheck...
# 9                                                NaN
#
#                          gpt-4-turbo_false_negatives  \
# 0                                                NaN
# 1                              [Arithmetic Overflow]
# 2                                                NaN
# 3                                                NaN
# 4                                    [Front Running]
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8  [Lack of Input Validation, Use of Deprecated S...
# 9                                                NaN
#
#                                               issues
# 0                                                NaN
# 1                              [Arithmetic Overflow]
# 2                                                NaN
# 3                                                NaN
# 4                                    [Front Running]
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8  [Lack of Input Validation, Reentrancy, Uncheck...
# 9                                                NaN
